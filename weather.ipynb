# %%
import pandas as pd
import csv
import codecs
import urllib.request
import urllib.error
import sys
from datetime import datetime, timedelta

# %%
BaseURL = ''
ApiKey = ''  # Replace 'YOUR_API_KEY' with your actual API key
UnitGroup = 'us'  # or 'metric' depending on your preference
Location = 'Eugene,%20OR'  # Location for the weather data

# Set start date to today's date
StartDate = datetime.now().strftime('%Y-%m-%d')

# Set end date to today's date + 7 days
EndDate = (datetime.now() + timedelta(days=7)).strftime('%Y-%m-%d')

ContentType = 'csv'  # Output format (CSV or JSON)
Include = 'days'  # Include sections (e.g., days, hours, current, alerts)

# Construct the weather data query
ApiQuery = f"{BaseURL}{Location}/{StartDate}/{EndDate}?unitGroup={UnitGroup}&contentType={ContentType}&include={Include}&key={ApiKey}"

# %%
ApiQuery = BaseURL + Location
if len(StartDate):
    ApiQuery += "/" + StartDate
    if len(EndDate):
        ApiQuery += "/" + EndDate

ApiQuery += "?"
if len(UnitGroup):
    ApiQuery += "&unitGroup=" + UnitGroup

if len(ContentType):
    ApiQuery += "&contentType=" + ContentType

if len(Include):
    ApiQuery += "&include=" + Include

ApiQuery += "&key=" + ApiKey

# %%
try:
    CSVBytes = urllib.request.urlopen(ApiQuery)
except urllib.error.HTTPError as e:
    ErrorInfo = e.read().decode()
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except urllib.error.URLError as e:
    ErrorInfo = e.read().decode()
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()

# %%
# Parse the results as CSV
CSVText = csv.reader(codecs.iterdecode(CSVBytes, 'utf-8'))

# Open a CSV file for writing
with open('raw_data/upcoming_weather.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)

    # Write headers
    for RowIndex, Row in enumerate(CSVText):
        if RowIndex == 0:
            writer.writerow(Row)
            FirstRow = Row
        else:
            # Write data rows
            writer.writerow(Row)
            print('Weather in', Row[0], 'on', Row[1])
            for ColIndex, Col in enumerate(Row):
                if ColIndex >= 4:
                    print('   ', FirstRow[ColIndex], '=', Row[ColIndex])
# Out:
# Weather in Eugene, OR, United States on 2024-06-04
#     temp = 60.2
#     feelslikemax = 69
#     feelslikemin = 53
#     feelslike = 60.2
#     dew = 52.8
#     humidity = 77
#     precip = 0
#     precipprob = 21
#     precipcover = 0
#     preciptype =
#     snow = 0
#     snowdepth = 0
#     windgust = 16.1
#     windspeed = 6.9
#     winddir = 228.9
#     sealevelpressure = 1016.5
#     cloudcover = 79.1
#     visibility = 10.1
#     solarradiation = 91.9
#     solarenergy = 8
#     uvindex = 4
#     severerisk = 10
#     sunrise = 2024-06-04T05:30:47
#     sunset = 2024-06-04T20:51:22
#     moonphase = 0.94
#     conditions = Partially cloudy
#     description = Partly cloudy throughout the day.
#     icon = partly-cloudy-day
#     stations = KCVO,WWCO3,KEUG
# Weather in Eugene, OR, United States on 2024-06-05
#     temp = 62.2
#     feelslikemax = 76
#     feelslikemin = 53
#     feelslike = 62.2
#     dew = 51.4
#     humidity = 71
#     precip = 0
#     precipprob = 5
#     precipcover = 0
#     preciptype =
#     snow = 0
#     snowdepth = 0
#     windgust = 15
#     windspeed = 8.1
#     winddir = 346.7
#     sealevelpressure = 1020.5
#     cloudcover = 34.7
#     visibility = 10.1
#     solarradiation = 329.5
#     solarenergy = 28.5
#     uvindex = 9
#     severerisk = 10
#     sunrise = 2024-06-05T05:30:25
#     sunset = 2024-06-05T20:52:05
#     moonphase = 0.97
#     conditions = Partially cloudy
#     description = Partly cloudy throughout the day.
#     icon = partly-cloudy-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-06
#     temp = 64.6
#     feelslikemax = 80
#     feelslikemin = 49
#     feelslike = 64.6
#     dew = 48.5
#     humidity = 58.9
#     precip = 0
#     precipprob = 0
#     precipcover = 0
#     preciptype =
#     snow = 0
#     snowdepth = 0
#     windgust = 16.1
#     windspeed = 8.1
#     winddir = 353.6
#     sealevelpressure = 1015.8
#     cloudcover = 4
#     visibility = 10.1
#     solarradiation = 357.1
#     solarenergy = 31
#     uvindex = 10
#     severerisk = 10
#     sunrise = 2024-06-06T05:30:06
#     sunset = 2024-06-06T20:52:45
#     moonphase = 0
#     conditions = Clear
#     description = Clear conditions throughout the day.
#     icon = clear-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-07
#     temp = 68.8
#     feelslikemax = 83.4
#     feelslikemin = 53.7
#     feelslike = 68.8
#     dew = 54.2
#     humidity = 61.9
#     precip = 0
#     precipprob = 1
#     precipcover = 0
#     preciptype =
#     snow = 0
#     snowdepth = 0
#     windgust = 11.6
#     windspeed = 6.3
#     winddir = 326.6
#     sealevelpressure = 1011.7
#     cloudcover = 9.5
#     visibility = 15
#     solarradiation = 350
#     solarenergy = 30.1
#     uvindex = 9
#     severerisk = 10
#     sunrise = 2024-06-07T05:29:48
#     sunset = 2024-06-07T20:53:24
#     moonphase = 0.04
#     conditions = Clear
#     description = Clear conditions throughout the day.
#     icon = clear-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-08
#     temp = 67.1
#     feelslikemax = 78.9
#     feelslikemin = 54.9
#     feelslike = 67.1
#     dew = 52.9
#     humidity = 62.3
#     precip = 0.067
#     precipprob = 6
#     precipcover = 4.17
#     preciptype = rain
#     snow = 0
#     snowdepth = 0
#     windgust = 13.2
#     windspeed = 7.2
#     winddir = 297
#     sealevelpressure = 1016.3
#     cloudcover = 40.8
#     visibility = 15
#     solarradiation = 323.9
#     solarenergy = 28
#     uvindex = 9
#     severerisk = 10
#     sunrise = 2024-06-08T05:29:33
#     sunset = 2024-06-08T20:54:01
#     moonphase = 0.07
#     conditions = Partially cloudy
#     description = Partly cloudy throughout the day.
#     icon = partly-cloudy-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-09
#     temp = 64.5
#     feelslikemax = 75.5
#     feelslikemin = 54.2
#     feelslike = 64.5
#     dew = 51.6
#     humidity = 64.6
#     precip = 0.02
#     precipprob = 8
#     precipcover = 4.17
#     preciptype = rain
#     snow = 0
#     snowdepth = 0
#     windgust = 15.2
#     windspeed = 7.4
#     winddir = 332.2
#     sealevelpressure = 1017.4
#     cloudcover = 29.3
#     visibility = 15
#     solarradiation = 352.5
#     solarenergy = 30.5
#     uvindex = 9
#     severerisk = 10
#     sunrise = 2024-06-09T05:29:20
#     sunset = 2024-06-09T20:54:37
#     moonphase = 0.11
#     conditions = Partially cloudy
#     description = Partly cloudy throughout the day.
#     icon = partly-cloudy-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-10
#     temp = 64.2
#     feelslikemax = 76.7
#     feelslikemin = 51.5
#     feelslike = 64.2
#     dew = 49.4
#     humidity = 61.2
#     precip = 0.004
#     precipprob = 5
#     precipcover = 4.17
#     preciptype = rain
#     snow = 0
#     snowdepth = 0
#     windgust = 15
#     windspeed = 7.4
#     winddir = 337.2
#     sealevelpressure = 1016
#     cloudcover = 7.2
#     visibility = 15
#     solarradiation = 365.1
#     solarenergy = 31.7
#     uvindex = 10
#     severerisk = 10
#     sunrise = 2024-06-10T05:29:10
#     sunset = 2024-06-10T20:55:10
#     moonphase = 0.14
#     conditions = Clear
#     description = Clear conditions throughout the day.
#     icon = clear-day
#     stations =
# Weather in Eugene, OR, United States on 2024-06-11
#     temp = 61.8
#     feelslikemax = 77.3
#     feelslikemin = 50.1
#     feelslike = 61.8
#     dew = 50.3
#     humidity = 67
#     precip = 0
#     precipprob = 9.7
#     precipcover = 0
#     preciptype =
#     snow = 0
#     snowdepth = 0
#     windgust = 14.3
#     windspeed = 8.9
#     winddir = 353.9
#     sealevelpressure = 1017.3
#     cloudcover = 9.7
#     visibility = 15
#     solarradiation = 337
#     solarenergy = 29.1
#     uvindex = 9
#     severerisk = 10
#     sunrise = 2024-06-11T05:29:01
#     sunset = 2024-06-11T20:55:42
#     moonphase = 0.17
#     conditions = Clear
#     description = Clear conditions throughout the day.
#     icon = clear-day
#     stations =

# %%
data = pd.read_csv('raw_data/upcoming_weather.csv')
print(data.columns)
data
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')
#                         name    datetime  tempmax  tempmin  temp  \
# 0  Eugene, OR, United States  2024-06-04     69.0     53.0  60.2
# 1  Eugene, OR, United States  2024-06-05     76.0     53.0  62.2
# 2  Eugene, OR, United States  2024-06-06     80.0     49.0  64.6
# 3  Eugene, OR, United States  2024-06-07     84.3     53.7  68.8
# 4  Eugene, OR, United States  2024-06-08     78.9     54.9  67.1
# 5  Eugene, OR, United States  2024-06-09     75.5     54.2  64.5
# 6  Eugene, OR, United States  2024-06-10     76.7     51.5  64.2
# 7  Eugene, OR, United States  2024-06-11     77.3     50.1  61.8
#
#    feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 0          69.0          53.0       60.2  52.8      77.0  ...          8.0
# 1          76.0          53.0       62.2  51.4      71.0  ...         28.5
# 2          80.0          49.0       64.6  48.5      58.9  ...         31.0
# 3          83.4          53.7       68.8  54.2      61.9  ...         30.1
# 4          78.9          54.9       67.1  52.9      62.3  ...         28.0
# 5          75.5          54.2       64.5  51.6      64.6  ...         30.5
# 6          76.7          51.5       64.2  49.4      61.2  ...         31.7
# 7          77.3          50.1       61.8  50.3      67.0  ...         29.1
#
#    uvindex  severerisk              sunrise               sunset  moonphase  \
# 0        4          10  2024-06-04T05:30:47  2024-06-04T20:51:22       0.94
# 1        9          10  2024-06-05T05:30:25  2024-06-05T20:52:05       0.97
# 2       10          10  2024-06-06T05:30:06  2024-06-06T20:52:45       0.00
# 3        9          10  2024-06-07T05:29:48  2024-06-07T20:53:24       0.04
# 4        9          10  2024-06-08T05:29:33  2024-06-08T20:54:01       0.07
# 5        9          10  2024-06-09T05:29:20  2024-06-09T20:54:37       0.11
# 6       10          10  2024-06-10T05:29:10  2024-06-10T20:55:10       0.14
# 7        9          10  2024-06-11T05:29:01  2024-06-11T20:55:42       0.17
#
#          conditions                           description               icon  \
# 0  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 1  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 2             Clear  Clear conditions throughout the day.          clear-day
# 3             Clear  Clear conditions throughout the day.          clear-day
# 4  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 5  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 6             Clear  Clear conditions throughout the day.          clear-day
# 7             Clear  Clear conditions throughout the day.          clear-day
#
#           stations
# 0  KCVO,WWCO3,KEUG
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
#
# [8 rows x 33 columns]
